# %% [markdown]
# # TP1 - Révisions sur les fonctions
# ## 1- Une fonction en Python
#
# Une fonction possède en général un nom, des entrées qui sont des **paramètres** (ou encore appelés **arguments**), et une sortie renvoyée généralement par l'instruction *return*.
#
#  <span style='color:green'>**Exemple 1**</span> :
#
# Exécutez la *cellule Code* suivantes (sélectionner la "cellule Code", puis cliquer sur *Exécuter* ou utiliser le raccourci clavier *CTRL + Entrée*).

# %%
def f(x):
    return 5*x-2

print(f(3))

# %% [markdown]
# Ici la fonction python a pour :
# * nom $f$.
# * paramètre $x$.
# * sortie le résultat du calcul $5x-2$ qui est renvoyé par l'instruction *return*.
#
# Il est à noter que :
# * la première ligne d'une fonction commence par *def* et se termine par : (deux-points).
# * Après le : (deux-points), à la ligne 2, il y a une indentation qui marque le début du corps de la fonction.
# * Lorsque l'indentation se termine, on sort de la fonction.
# * Lorsque vous faites un appel de fonction, vous devez impérativement préciser la valeur du ou des paramètres. Ligne 4 : f(3). Le paramètre $x$ prend la valeur 3.
# * le parenthésage dans l'instruction *print()* est obligatoire contrairement à l'instruction *return*.
#
# <span style='color:green'>**Exemple 2**</span> : une fonction peut avoir plusieurs paramètres.
#
#  Soient $A(x_A,y_A)$ et $B(x_B,y_B)$ dans un repère orthonormé. On sait que $AB=\sqrt{(x_B-x_A)^{2}+(y_B-y_A)^{2}}$.
#
#  Voici un script qui calcule la distance $AB$ en fonction des coordonnées de $A$ et $B$.

# %%
from math import *
def distance(xA,yA,xB,yB):
    AB=sqrt((xB-xA)**2+(yB-yA)**2)
    return AB

print(round(distance(1,2,3,4),2)) #round(AB,2) donne une approximation de AB à 2 chiffres après la virgule

# %% [markdown]
#  <span style='color:green'>**Exemple 3**</span> : une fonction peut ne pas avoir de paramètres
#
#  En voici un exemple que vous pouvez tester.

# %%
from random import *
def jeu():
    toto=randint(1,6) # randint(1,6) renvoie un entier aléatoire de 1 à 6 (1 et 6 compris)
    print(toto)
    if toto==6:
        return "Gagné !"
    else :
        return "Perdu !"
    
print(jeu())

# %% [markdown]
# Après l'instruction *print* dans une fonction, la ligne d'après est exécutée. Ici, après le *print(toto)* de la ligne 4, la ligne 5 est exécutée.
#
# Après l'instruction *return*, la fonction est stoppée, le programme se poursuit ici à la ligne 10.
#
# Vous pouvez le tester grâce au programme suivant ("Toto" et "Titi" ne sont jamais affichés) :

# %%
from random import *
def jeu():
    ord=randint(1,6) # randint(1,6) renvoie un entier aléatoire de 1 à 6 (1 et 6 compris)
    print(ord)
    if ord==6:
        return "Gagné !"
        print("Toto")
    else :
        return "Perdu !"
        print("Titi")
    
print(jeu())

# %% [markdown]
#  <span style='color:green'>**Exemple 4**</span> : une fonction peut ne pas contenir de *return*
#
#  Elle peut par exemple afficher un résultat par l'intermédiaire de l'instruction *print*.
#
#  En voici un exemple que vous pouvez tester.

# %%
def accueil():
    print("Bonjour")

print(accueil())

# %% [markdown]
# Lors de l'exécution, il est aussi affiché en deuxième ligne *None*. Cela signifie que comme il n'y a pas de *return*, cette instruction ne renvoie rien par l'instruction *return*, d'où le *None*. En général lorsqu'une **fonction** ne contient pas de *return*, c'est une **procédure**.

# %% [markdown]
# ## 2- Exercices
#
# <span style='color:blue'>**Exercice 1**</span> :
# Ecrire dans la *cellule Code* une fonction *double(a)* qui renvoie le double du nombre a.

# %%
def double(a):
    ...
    
print(double(10))
print(double(100))

# %% [markdown]
# <span style='color:blue'>**Exercice 2**</span> :
#
# Ecrire dans la cellule Code ci-après une fonction *fonct(x)* qui renvoie l’image de $x$ par la fonction mathématique
# $f ( x )=-2 x²+3 x+1$
#
# *Remarque : a² se note a**2*

# %%
def fonct(x):
    ...
    
print(fonct(1))
print(fonct(-5))

# %% [markdown]
# <span style='color:blue'>**Exercice 3**</span> :
#
# Ecrire une fonction de deux paramètres *moyenne(a,b)* qui renvoie la moyenne des deux nombres a et b.

# %%
def moyenne(a,b) :
    ...
    
print(moyenne(3,5))
print(moyenne (-2,2))

# %% [markdown]
# <span style='color:blue'>**Exercice 4**</span> :
#
# Ecrire une fonction *de( )* (fonction sans argument) renvoyant un nombre au hasard entre 1 et 6 afin de simuler un lancer de dé.
#
# Indications :
#
# -l’instruction randint(a,b) renvoie un entier au hasard entre a et b.
#
# -il faut écrire au tout début du programme
# *from random import**, car cette instruction n’est pas par défaut dans la mémoire de Python.

# %%
from random import*
def de() :
    ...

# %% [markdown]
# <span style='color:blue'>**Exercice 5**</span> :
#
# Ecrire une fonction *solde* qui renvoie le prix d'un article lorsque l'utilisateur donne le prix initial et la remise en %.

# %%
def solde(prix,taux) :
    ...

# %% [markdown]
# <span style='color:blue'>**Exercice 6**</span> :
#
# Compléter la fonction *pave(h,L,l)* pour qu'elle affiche l'aire des 6 faces du pavé droit en plus de son volume (On appliquera alors la fonction dans le cas où $h=3$, $L=4$ et $l=2$) :
#
# ![image1](image1TP1.png)

# %%
def pave(h,L,l):
    ...

print(pave(3,4,2))

# %% [markdown]
# <span style='color:blue'>**Exercice 7**</span> :
#
# Ecrire une fonction donnant les coordonnées de la représentation graphique d'un polynôme de degré 2 connaissant ses coefficients $a, b, c$.
